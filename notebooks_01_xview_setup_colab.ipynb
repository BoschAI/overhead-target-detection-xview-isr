# %% [markdown]
# <a href="https://colab.research.google.com/github/BoschAI/overhead-target-detection-xview-isr/blob/master/notebooks_01_xview_setup_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
